# %%
# !pip install tensorflow-gpu==1.15
# import keras==2.2.4
import numpy as np  
import pandas as pd 
import re           
import os
from bs4 import BeautifulSoup 
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords   
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# !pip install wget
import wget
import nltk
# Out:
# Collecting tensorflow-gpu==1.15
#   Downloading https://files.pythonhosted.org/packages/a5/ad/933140e74973fb917a194ab814785e7c23680ca5dee6d663a509fe9579b6/tensorflow_gpu-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (411.5MB)
#      |████████████████████████████████| 411.5MB 40kB/s
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.0.8)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (3.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.1.0)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 37.7MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.8.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (3.2.1)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 37.1MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.9.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.12.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.28.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.34.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.12.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.18.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.15) (46.3.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15) (3.2.1)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=62f4891a24fa31d792311866dc715fdc3aca32a0102ea17958670526b5447d08
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.2.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 1.15.0 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorflow-estimator<2.3.0,>=2.2.0, but you'll have tensorflow-estimator 1.15.1 which is incompatible.
# ERROR: tensorflow-probability 0.10.0rc0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: tensorflow-estimator, gast, tensorboard, tensorflow-gpu
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
# Successfully installed gast-0.2.2 tensorboard-1.15.0 tensorflow-estimator-1.15.1 tensorflow-gpu-1.15.0
# Using TensorFlow backend.
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=1ecdde16253403a21386aec5a24eaa5bbf346421f9004bbd43ffd2394cebedfa
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/text_summarizer_datasets/amazon-fine-food-reviews.zip'
# Out:
# Archive:  /content/drive/My Drive/text_summarizer_datasets/amazon-fine-food-reviews.zip
#   inflating: Reviews.csv
#   inflating: database.sqlite
#   inflating: hashes.txt

# %%
data=pd.read_csv("/content/Reviews.csv",nrows=100000)
data[['Text','Summary']].sample(5)
# Out:
#                                                                                                                                                                                                           Text                                                Summary
# 7681   We have been using Meyenberg's powdered goat milk for several years.  We used to buy their milk in cartons at Walmart and it was good.  The only problem was that we live so far from a Walmart stor...  The most convienent way to store and drink goats milk
# 17760  GROSS. Tastes like salty menthol sugar or something. Might be passable if you're hiding it in something you're baking...but for coffee? NAH. If you don't own a dog, use Xylitol, because Xylitol wi...              This is the first time I tried Erythritol
# 78303  I have reordered this curry four times now and i will continue to reorder! It is super yummy! I prefer the mild but it is not available for this same deal. If i were to buy these at my Asian marke...                                         a REPEAT order
# 42672  I would say that the Timothy's Hazelnut coffee has a rather nice flavor.  The coffee is medium mild in strength, probably a 5 on a 1-10 scale for strong coffee taste.<br /><br />I find the hazelnu...                                   Nice Hazelnut Coffee
# 85668  I have used this for at least 25 years.  I do not like spicy things so this is perfect as it's mild yet flavorful.  I use for beef enchiladas but also add to my hamburger for tacos, burritos, etc....                                       Best Mild Flavor

# %%
data.drop_duplicates(subset=['Text'],inplace=True)  #dropping duplicates
data.dropna(axis=0,inplace=True)

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",

                           "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",

                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",

                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",

                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",

                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",

                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",

                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",

                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",

                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",

                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",

                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",

                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",

                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",

                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",

                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",

                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",

                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",

                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",

                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",

                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",

                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",

                           "you're": "you are", "you've": "you have"}

# %%
data['Text'][:10]
# Out:
# 0    I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1             Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2    This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3    If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4                                                               Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
# 5    I got a wild hair for taffy and ordered this five pound bag. The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc. My only complaint is there wa...
# 6    This saltwater taffy had great flavors and was very soft and chewy.  Each candy was individually wrapped well.  None of the candies were stuck together, which did happen in the expensive version, ...
# 7                                                               This taffy is so good.  It is very soft and chewy.  The flavors are amazing.  I would definitely recommend you buying it.  Very satisfying!!
# 8                                                                        Right now I'm mostly just sprouting this so my cats can eat the grass. They love it. I rotate it around with Wheatgrass and Rye too
# 9                                                                  This is a very healthy dog food. Good for their digestion. Also good for small puppies. My dog eats her required amount at every feeding.
# Name: Text, dtype: object

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english')) 
def text_cleaner(text):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    tokens = [w for w in newString.split() if not w in stop_words]
    long_words=[]
    for i in tokens:
        if len(i)>=3:                  #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
data['Summary'][:10]
# Out:
# 0                            Good Quality Dog Food
# 1                                Not as Advertised
# 2                            "Delight" says it all
# 3                                   Cough Medicine
# 4                                      Great taffy
# 5                                       Nice Taffy
# 6    Great!  Just as good as the expensive brands!
# 7                           Wonderful, tasty taffy
# 8                                       Yay Barley
# 9                                 Healthy Dog Food
# Name: Summary, dtype: object

# %%
def summary_cleaner(text):
    newString = re.sub('"','', text)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    newString = newString.lower()
    tokens=newString.split()
    newString=''
    for i in tokens:
        if len(i)>1:                                 
            newString=newString+i+' '  
    return newString

#Call the above function
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(summary_cleaner(t))

data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary
data['cleaned_summary'].replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
data['cleaned_summary'] = data['cleaned_summary'].apply(lambda x : '_START_ '+ x + ' _END_')

# %%
for i in range(5):
    print("Review:",data['cleaned_text'][i])
    print("Summary:",data['cleaned_summary'][i])
    print("\n")
# Out:
# Review: bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# Summary: _START_ good quality dog food  _END_
#
#
# Review: product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# Summary: _START_ not as advertised  _END_
#
#
# Review: confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch
# Summary: _START_ delight says it all  _END_
#
#
# Review: looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# Summary: _START_ cough medicine  _END_
#
#
# Review: great taffy great price wide assortment yummy taffy delivery quick taffy lover deal
# Summary: _START_ great taffy  _END_

# %%
import matplotlib.pyplot as plt
text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})
length_df.hist(bins = 30)
plt.show()

# %%
max_len_text=80 
max_len_summary=10
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(data['cleaned_text'],data['cleaned_summary'],test_size=0.1,random_state=0,shuffle=True)

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr,  maxlen=max_len_text, padding='post') 
x_val   =   pad_sequences(x_val, maxlen=max_len_text, padding='post')

x_voc_size   =  len(x_tokenizer.word_index) +1

# %%
#preparing a tokenizer for summary on training data 
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

#convert summary sequences into integer sequences
y_tr    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr, maxlen=max_len_summary, padding='post')
y_val   =   pad_sequences(y_val, maxlen=max_len_summary, padding='post')

y_voc_size  =   len(y_tokenizer.word_index) +1

# %%
# !wget 'http://nlp.stanford.edu/data/glove.6B.zip'
# !unzip '/content/glove.6B.zip'
# Out:
# --2020-05-19 10:45:24--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2020-05-19 10:45:25--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2020-05-19 10:45:25--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  1.85MB/s    in 6m 29s
#
# 2020-05-19 10:51:54 (2.12 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]
#
# Archive:  /content/glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
# GLOVE_DIR = path for glove.6B.100d.txt
def glove_100d_dictionary(GLOVE_DIR):
  embeddings_index = {}
  f = open(os.path.join(GLOVE_DIR, 'glove.6B.100d.txt'))
  for line in f:
      values = line.split()
      word = values[0]
      coefs = np.asarray(values[1:], dtype='float32')
      embeddings_index[word] = coefs
  f.close()
  return embeddings_index

# %%
embeddings_index = {}
f = open(os.path.join('/content', 'glove.6B.100d.txt'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
word_index = x_tokenizer.word_index
embedding_matrix = np.zeros((len(word_index) + 1, 100))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
import tensorflow as tf
import os
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import backend as K


class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state """

            assert_msg = "States must be a list. However states {} is of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch_size*en_seq_len, latent_dim
            reshaped_enc_outputs = K.reshape(encoder_out_seq, (-1, en_hidden))
            # <= batch_size*en_seq_len, latent_dim
            W_a_dot_s = K.reshape(K.dot(reshaped_enc_outputs, self.W_a), (-1, en_seq_len, en_hidden))
            if verbose:
                print('wa.s>',W_a_dot_s.shape)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>',U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            reshaped_Ws_plus_Uh = K.tanh(K.reshape(W_a_dot_s + U_a_dot_h, (-1, en_hidden)))
            if verbose:
                print('Ws+Uh>', reshaped_Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.reshape(K.dot(reshaped_Ws_plus_Uh, self.V_a), (-1, en_seq_len))
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """
            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        def create_inital_state(inputs, hidden_size):
            # We are not using initial states, but need to pass something to K.rnn funciton
            fake_state = K.zeros_like(inputs)  # <= (batch_size, enc_seq_len, latent_dim
            fake_state = K.sum(fake_state, axis=[1, 2])  # <= (batch_size)
            fake_state = K.expand_dims(fake_state)  # <= (batch_size, 1)
            fake_state = K.tile(fake_state, [1, hidden_size])  # <= (batch_size, latent_dim
            return fake_state

        fake_state_c = create_inital_state(encoder_out_seq, encoder_out_seq.shape[-1])
        fake_state_e = create_inital_state(encoder_out_seq, encoder_out_seq.shape[1])  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
from keras import backend as K 
K.clear_session() 
latent_dim = 500 

# Encoder 
encoder_inputs = Input(shape=(max_len_text,)) 
enc_emb = Embedding(x_voc_size, 100, weights=[embedding_matrix],input_length=max_len_text, trainable=False)(encoder_inputs) 

#LSTM 1 
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb) 

#LSTM 2 
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1) 

#LSTM 3 
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True) 
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2) 

# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
dec_emb_layer = Embedding(x_voc_size, 100, weights=[embedding_matrix],input_length=max_len_text, trainable=False) 

dec_emb = dec_emb_layer(decoder_inputs) 

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True) 
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c]) 

#Attention Layer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs]) 

# Concat attention output and decoder LSTM output 
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#Dense layer
decoder_dense = TimeDistributed(Dense(y_voc_size, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs) 
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 80, 100)      5157100     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 80, 500), (N 1202000     embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 80, 500), (N 2002000     lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 100)    5157100     input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 80, 500), (N 2002000     lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 500),  1202000     embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 500),  500500      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 1000)   0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 14096)  14110096    concat_layer[0][0]
# ==================================================================================================
# Total params: 31,332,796
# Trainable params: 21,018,596
# Non-trainable params: 10,314,200
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
x_tr
y_tr[:,:-1]
y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:]
# Out:
# array([[[  13],
#         [  14],
#         [   2],
#         ...,
#         [   0],
#         [   0],
#         [   0]],
#
#        [[  34],
#         [ 168],
#         [  46],
#         ...,
#         [   0],
#         [   0],
#         [   0]],
#
#        [[4593],
#         [   2],
#         [   0],
#         ...,
#         [   0],
#         [   0],
#         [   0]],
#
#        ...,
#
#        [[   7],
#         [  59],
#         [ 172],
#         ...,
#         [   0],
#         [   0],
#         [   0]],
#
#        [[  71],
#         [ 601],
#         [   2],
#         ...,
#         [   0],
#         [   0],
#         [   0]],
#
#        [[   5],
#         [  12],
#         [   2],
#         ...,
#         [   0],
#         [   0],
#         [   0]]], dtype=int32)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=512, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 79516 samples, validate on 8836 samples
# Epoch 1/50
# 79516/79516 [==============================] - 109s 1ms/sample - loss: 3.3416 - val_loss: 2.8869
# Epoch 2/50
# 79516/79516 [==============================] - 104s 1ms/sample - loss: 2.8973 - val_loss: 2.6855
# Epoch 3/50
# 79516/79516 [==============================] - 105s 1ms/sample - loss: 2.7022 - val_loss: 2.5298
# Epoch 4/50
# 79516/79516 [==============================] - 104s 1ms/sample - loss: 2.5401 - val_loss: 2.4494
# Epoch 5/50
# 79516/79516 [==============================] - 104s 1ms/sample - loss: 2.4132 - val_loss: 2.3741
# Epoch 6/50
# 79516/79516 [==============================] - 104s 1ms/sample - loss: 2.3119 - val_loss: 2.3238
# Epoch 7/50
# 79516/79516 [==============================] - 105s 1ms/sample - loss: 2.2235 - val_loss: 2.2898
# Epoch 8/50
# 79516/79516 [==============================] - 103s 1ms/sample - loss: 2.1411 - val_loss: 2.2954
# Epoch 00008: early stopping

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend() 
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word 
reverse_source_word_index=x_tokenizer.index_word 
target_word_index=y_tokenizer.word_index

# %%
# encoder inference
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_len_text,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    # print('input_seq: {}, e_out: {} '.format(input_seq,e_out))
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Chose the 'start' word as the first word of the target sequence
    target_seq[0, 0] = target_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        # print("sampled_token:",sampled_token)
        if(sampled_token!='end'):
            decoded_sentence += ' '+sampled_token

            # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'end' or len(decoded_sentence.split()) >= (max_len_summary-1)):
                stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index
        # stop_condition = True
        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
      if((i!=0 and i!=target_word_index['start']) and i!=target_word_index['end']):
        newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
      if(i!=0):
        newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(len(x_val)):
  print("Review:",seq2text(x_val[i]))
  print("Original summary:",seq2summary(y_val[i]))
  print("Predicted summary:",decode_sequence(x_val[i].reshape(1,max_len_text)))
  print("\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# Original summary: best canned clams have ever used
# Predicted summary:  great soup
#
#
# Review: miss old waffle pancake mix using wonderful product mix oatmeal cases makes wonderful waffles pretty easy give gluten mix
# Original summary: love my bisquick from amazon
# Predicted summary:  great pancakes
#
#
# Review: really enjoy eating oatmeal taste great flavoring liking awesome love organic good price love going subscribe
# Original summary: best oatmeal ever
# Predicted summary:  great taste
#
#
# Review: cat severe allergic reaction food resulting deep crusty oozing lesions face around mouth ears neck close examination ingredients one unusual additive sunflower seed oil fussie cat flavors back old food healing nicely stick less expensive brands save vet bills
# Original summary: read the ingredient list first
# Predicted summary:  my cats love it
#
#
# Review: tiny bit grainy bother bit kids really like use chocolate syrup substitute kids milk make box really love great drinking full strength sweet love
# Original summary: this milk is really good
# Predicted summary:  not the same
#
#
# Review: love banana nut bread bars like better cold good warmed try love
# Original summary: yum
# Predicted summary:  delicious
#
#
# Review: realize vendor reviews separate area dealing perishable items vendor make difference quality item therefore also review item skeptical ordering produce fashion positive reviews desire ingredients glad took chance order arrived two days earliest delivery estimate high heat right makes big difference fact well packed obviously fresh produce begin items excellent quality generous portions make insane amount tom yum soup enough left throw together delicious dishes give try think pleased
# Original summary: impressed
# Predicted summary:  great product
#
#
# Review: tried several tassimo discs gevalia best coffee ever tasted coffee snob love coffee
# Original summary: great coffee
# Predicted summary:  best coffee ever
#
#
# Review: tried several low carb breads search proven best one far regular bread texture works great sandwiches nice tender toasted piece good toasted also low carb bread husband low carb diet thought sandwich noon good bread think texture perfect course sandwiches
# Original summary: my favorite low carb bread
# Predicted summary:  great bread
#
#
# Review: come conclusion making coffee one cup time much better big bitter pot sitting simmering bought melitta coffee cones use filters although filters made cones wish slightly taller careful overfill filter water reason sometimes buy filters trim bit case thinking buying bleached white filters two filter cones tried side side one white filter one brown brown filters much faster tend clog like white ones fyi
# Original summary: sometimes simple is better
# Predicted summary:  great coffee
#
#
# Review: organic love whole grain crackers drizzled local raw honey keep carbs fats protein balanced also usually add chocolate rice protein well healthy sea salt teaspoon ground flax blend butter spread really doctor mask taste great big healthy stuff another great thing sunflower butter good source vitamin also magnesium mineral many need enough also purpose green lid fits cute glass salsa jar also purpose also keep seed nut butters frig door think sunbutter consistency improved company also suggests maintain freshness enjoy
# Original summary: yummy sunny seed butter
# Predicted summary:  great healthy snack
#
#
# Review: could find sugar belgium summer looked everywhere found line ordered within days returning home thanks
# Original summary: sweet
# Predicted summary:  great sugar free
#
#
# Review: expecting variety flavor different pods tasted quite similar biggest complaint every pods would produce espresso got water even trying run espresso machine second time sticking espressione brand next purchase since flavor result consistent
# Original summary: decent value
# Predicted summary:  not bad
#
#
# Review: many different people family tried coffee yet offend anyone mild easy drink filter packs easy store threw freezer would recommend reclosable bags packs use ziplock bag
# Original summary: very good coffee at decent price
# Predicted summary:  great coffee
#
#
# Review: perfect union taste health combined rolled oats flax seeds coconut natural chocolate flavor natural vanilla flavor dried strawberries dried raspberries chunks dark chocolate organic snack keep heart healthy happy berries keep artery vein walls strong flexible dark chocolate oats keep body really strong father ancestors lived flax farm lived know fact flax keeps cholesterol super low heart super healthy benefits get super snack unbelievable taste beyond delicious love cholesterol free low sodium low calorie snack benefits eating treat love even
# Original summary: love the taste but love the health benefits more
# Predicted summary:  delicious
#
#
# Review: heard great things sassafras wanted try worried taste turned lot better anticipated actually gonna order pack continue drinking time trust fda
# Original summary: better taste than expected
# Predicted summary:  not bad
#
#
# Review: first purchase gluten free cheese curls pleasantly surprised taste crunch husband even likes picky snack foods taste better name brand cheese curls less fat calories
# Original summary: michael seasons baked cheddar cheese curls
# Predicted summary:  not bad
#
#
# Review: month old loves pouches great way getting broccoli diet started able recently although sometimes messy wish available larger size ounces lot toddler finish minute would want also loves spinach mango pear happy baby pouches bigger
# Original summary: my daughter loves this
# Predicted summary:  my son loves these
#
#
# Review: antlers great natural treat small dogs bought first antler piece trainer recommended preservative free product pieces purchased amazon small little dogs like month old chihuahuas last long time prefer bully sticks rawhides cause tummy upset difficulties pups stool small dogs like mine minutes bully stick today means rumbling tummy tomorrow first introduced antler piece female barked ran away male immediately took sister give try loves much sit anything get antler another plus let bring antler onto lap slimy bully sticks
# Original summary: great natural treat
# Predicted summary:  my dogs love them
#
#
# Review: drink delicious tea almost every day yet find anything like market
# Original summary: love it
# Predicted summary:  love this tea
#
#
# Review: quaker soft baked oatmeal cookies indeed soft individual wrapping cookie ensures stay soft fresh ready eat unfortunately bland tasting surprise quaker products would buy expect flavorful cookie trade soft fresh flavorful looking cookies excite taste buds afraid look elsewhere
# Original summary: soft and fresh
# Predicted summary:  not bad but not great
#
#
# Review: wanted like product trying eliminate splenda diet hoping would something could use unfortunately like tastes like alka seltzer flavorings thrown
# Original summary: wish did
# Predicted summary:  not bad
#
#
# Review: smartfries awsome regular chips bagged snacks get maybe per serving smartfries get per serving calories never even get close many though usually get fix around love trader joe skinny fries luck thing price purchased multiple bag packs frequent buyer product
# Original summary: great guilt free snack much better than chips
# Predicted summary:  great chips
#
#
# Review: like baste heavily pork roast serve extra side family loves
# Original summary: great taste
# Predicted summary:  great rub
#
#
# Review: purchased snack workouts find snacking time really good come variety flavors
# Original summary: good after workout snack
# Predicted summary:  great snack
#
#
# Review: lazy cannot find real mint tea dead winter tea lazy want wash spoon muddle leaves brink summer tea diet tea neat refreshing sweet hot cold
# Original summary: nd from the original mint tea
# Predicted summary:  not bad
#
#
# Review: tried cat food month old kitten used two weeks thinking stomach would get used wrong cat food made cat crap like pound man gosh stink cat food turned cute little fur ball feline ball gas longer wanted lap matter house kid two weeks cat food cat actually protruding went back cat food giving within two weeks back normal never
# Original summary: bad
# Predicted summary:  my cats love it
#
#
# Review: recently started using cups sure quality intensity would par wound trying many standard cups part great barista prima french roast well worth trying intense flavorful concerns throwing away old coffee pot
# Original summary: finally coffee that makes cups worth to
# Predicted summary:  great coffee
#
#
# Review: coffee tastes nasty cannot even drink disgusting cannot believe anything bitter acid free actually threw away two bags
# Original summary: the worst tasting coffee have ever tasted
# Predicted summary:  tastes like plastic
#
#
# Review: cats none eat peas product unless take fork mash peas hard hard mash get product
# Original summary: cats do not like peas and eat around them
# Predicted summary:  not the same
#
#
# Review: emerald harmony original trail mix great eat snack cereal salad always share trail mix family friends facebook church members reply receive great good eat delicious take word try trail mix want buy different type great trail mix price great size bags cannot found brand stores florida
# Original summary: emerald harmony original trail mix
# Predicted summary:  delicious
#
#
# Review: work call center talk day long air dry area best relief found throat comfort tea coats throat nice taste even drink home working like much saw wild oats tried long keep making buy use way amazon best price buy quanity looked seen better offer
# Original summary: great for call center work
# Predicted summary:  great tea
#
#
# Review: one best teas enjoy cup tea every evening would change thing
# Original summary: the best tea
# Predicted summary:  great tea
#
#
# Review: nights prepping food storage shelf stable food lasts long time sitting pantry also easy use adding water perfect emergencies times may unable get store simmer water satisfying meal whole family stuff potlucks hate times last minute remember potluck work following day problem get large crockpot cupboard cook however like night store fridge throw crock pot next day hour time add paper bowls bag oyster shaped crackers plastic spoons bringing home empty crockpot really versatile great tasting soup perfect item hand
# Original summary: great soup very versatile
# Predicted summary:  great food
#
#
# Review: looking cup tea tastes like tea twist lemon like hot cup lemon little tea imagine could overwhelming people like lemon star good hot poured ice wish would make lime zinger cup well
# Original summary: they re not kidding about the lemon part
# Predicted summary:  not bad
#
#
# Review: tall advertised kept like alot shining star indoor bonsai collection stunning like forest kitchen months thriving
# Original summary: great tree
# Predicted summary:  great product
#
#
# Review: tried black raspberry orange mango loved care much pineapple coconut strawberry one black raspberry orange great addition want something regular water want pop
# Original summary: great water alternative
# Predicted summary:  delicious
#
#
# Review: big fan kashi foods general bars absolute favorite love crunchy chewy texture chocolate peanut flavor really good sweet remind healthier version home made special bars
# Original summary: great quick and easy breakfast
# Predicted summary:  love these
#
#
# Review: ordered product could find local stores small dogs wirh continual teeth issues since using mini bites needed teeth cleaned rhe vet love taste win win
# Original summary: crunch clean mini bites
# Predicted summary:  my dogs love them
#
#
# Review: never without mild flavored tea much enjoyable plain green tea everyone serve surprised pleasant flavor several buy
# Original summary: favorite
# Predicted summary:  not bad
#
#
# Review: regular breakfast coffee great way start day want coffee flavors extra caffeine goto coffee fully awake
# Original summary: good coffee
# Predicted summary:  great coffee
#
#
# Review: like popcorn small crunchy
# Original summary: crunchy popcorn
# Predicted summary:  great popcorn
#
#
# Review: joint care important dog start early symptoms appear helps ward symptoms longer start joint care early dog life ask vet
# Original summary: joint care is very important
# Predicted summary:  great product
#
#
# Review: usually feed dog border collie english shepherd rescue best food possible figured would give whirl loved granted love ingredient list things like soy corn meal animal fat something intend feed dog keep best health something would buy time food source giving treat times week keep things interesting beef vegetables good many things would keep feeding daily basis
# Original summary: he loves it but do not
# Predicted summary:  great dog food
#
#
# Review: love stuff eaten sonny find sale online great
# Original summary: sonny sweet bbq sauce oz
# Predicted summary:  love these
#
#
# Review: strong use small setting half amount strength french roast cups wanting save little money trying san francisco bay cups really working way use cups small cup setting fill big coffee mug price wise comes paying others excellent strong good flavor kind like come packaged individual plastic bags big deal put little jar container machine regular coffee maker different sure others feel problem hope helps anyone considering buying brand would definitely recommend would give stars taste making large mug strong like
# Original summary: great flavor but not as strong as other brands
# Predicted summary:  great cup of coffee
#
#
# Review: recently purchased several bottles tiny certainly get job done put two drops homemade creamer definitely english toffee flavor also buyer ships quickly great product
# Original summary: great little product
# Predicted summary:  not the same
#
#
# Review: concerned seen blossoms since arrival lots green leaves
# Original summary: arrived in timely fashion
# Predicted summary:  not what expected
#
#
# Review: wild ride beef jerkey incredibly tender flavorful jerky products tried past like flavored shoe leather definitely heads shoulders others actually substance fact low fat preservatives big selling point like spicey try black pepper one
# Original summary:
# Predicted summary:  not bad but not great
#
#
# Review: natural lemon bar include processed ingredients love stuff eat one every day
# Original summary: great flavor
# Predicted summary:  great taste
#
#
# Review: pumpkin spice latte opinion due fact creamier lower calorie much healthier tried two matchas one better however sucker pumpkin finished big container roasted salted pepitas lowes foods three days make pour quarter cup milk mug heat microwave twenty seconds whisk half teaspoon matcha powder fork fill mug rest way milk add half teaspoon sugar heat warm cozy different cocoa healthier cocoa good switch really cocoa wintertime stuff worth shot worst get hot rich anti oxidants really good pumpkin could bad
# Original summary: warm and rich and pumpkin
# Predicted summary:  not so good
#
#
# Review: stuff works doesnt taste bad keep going aftertaste drinks
# Original summary: it works like it says
# Predicted summary:  tastes like plastic
#
#
# Review: sunflowers seeds great quality every bag flavor salt pepper bold love shipping service company great every time ordered
# Original summary: sunflower seeds
# Predicted summary:  great seeds
#
#
# Review: like special granola bars chewy consistency sweetness flavors chocolate peanut butter strong way granola generic term days would also liked bit crunch mix slightly powdery aftertaste seems common protein added snack bars found tasty coffee could really give higher average marks nothing particularly exceptional going looking low ish calorie snack decent fiber protein could worse keeping box desk drawer
# Original summary: if you like rice treats
# Predicted summary:  not bad but not great
#
#
# Review: absolutely best product available make mayonnaise however buying local market means taking second therefore buy online quantity save local market price
# Original summary: colman mustard
# Predicted summary:  great product
#
#
# Review: treats well liked dogs right size smell feel gross hands really sure else say except organic important seem one options dog treats buy
# Original summary: dogs love em
# Predicted summary:  my dog loves these
#
#
# Review: amazing fondant fondarific convenient get amazon easy use nice taste would definitely recommend anyone passion cake decorating
# Original summary: fondarific fondant
# Predicted summary:  great product
#
#
# Review: bad hummus make tahini doesnt taste like hummus pomeranian restaurants
# Original summary:
# Predicted summary:  not bad
#
#
# Review: never sampled flavor took chance ordered pack sounded delicious happy say made right choice excellent combination chocolate raspberry one flavor overpower new favorite cup definitely buy supply runs
# Original summary: decadent coffee
# Predicted summary:  delicious
#
#
# Review: ordered amazon reading reviews glad pudding really easy make add skim milk stir medium heat minutes delicious pudding ready let cool little longer mentioned pack makes pudding thicker tasty
# Original summary: love the jell tapioca pudding
# Predicted summary:  delicious
#
#
# Review: far best thing ever taste fantastic goes well everything found making excuses eat everything possibly could personally find addictive thing ever tasted smell alone reason enough buy
# Original summary: the best stuff in the world
# Predicted summary:  tastes like like real
#
#
# Review: like candy coconut need look candy bought put friends first timers peach buds thought immediately wanted know get
# Original summary: this product is amazing
# Predicted summary:  great candy
#
#
# Review: great cookies overly sweet american cookies hint citrus could ask cookies box decadent treat
# Original summary: yummy
# Predicted summary:  delicious cookies
#
#
# Review: boxes candy sticks broken arrival email told new boxes would shipped never came emailed monday wedding saturday assured would new ones wedding candy buffet new box arrived monday wedding box broken customer service nice trying help however price paid thought could better
# Original summary: bad purchase
# Predicted summary:  not the same
#
#
# Review: pet sitter recommended product always trust sure enough keeper expensive side dogs worth easy ready alternative raw food diet good sprinkling dry food
# Original summary: great product
# Predicted summary:  great product
#
#
# Review: almonds unbelievable amount salt love salt top bought brand stores never salty maybe machine went wacko processing cannot eat unless take time try wipe salt talks forever
# Original summary: too salty to eat
# Predicted summary:  not the same
#
#
# Review: ordered tootsie roll pops thinking original flavors got green apple strawberry cherry chocolate blue raspberry watermelon advertisement blurb amazon site indicated flavors original flavors want ship whole order back used ones order ordering another supplier previously used represented correct box cautious order amazon site indicate exact flavors call find got misrepresented flavors easy even find got wrong type main lesson check supplier else fails may use trial error get correct item
# Original summary: misrepresentation
# Predicted summary:  not what expected
#
#
# Review: stars red dawned red seen red since prefer red food dyed nuts nostalgic seniors like see red horrible red food dyed imagine love natural colored someone teeth tiny fake red particles knowing popular colored ones makes wonder would guess red ones fifty left grant warehouse shipment lost sea turkey great turkey red taking wal mart consideration factoring shipping normal color red cost tha pound max unless run ning president somethin pass red ones half price hell wants red fingers devil
# Original summary: red pistachios
# Predicted summary:  not bad but not great
#
#
# Review: shared two older sons ordered great put glove compartment work
# Original summary: these are great snack
# Predicted summary:  great product
#
#
# Review: calories fiber vitamin zinc kellog fiber plus also saturated fat fewer proteins another problem pure natural bars promoted gluten free vegan natural ingredients give natural processed plant also processes wheat peanuts soy sesame negates gluten free statement plus find bars use natural organic ingredients definitely would call either bar healthy chocolate bar better typical chocolate bar would recommend trying kellog fiber plus first liking try pure naturals bars eat sure buy pure natural bars likely costly compared kellog fiber plus
# Original summary: somewhat tasty but mostly mediocre
# Predicted summary:  great product
#
#
# Review: ordered item children church easter church events children important take responsibility seriously item items ordered amazon com saved bunches money purchased elsewhere knows
# Original summary: fresh timely shipping great prices
# Predicted summary:  great service
#
#
# Review: flavors equal choose carefully find one matches taste buds personally love cherry pie needs snack
# Original summary: love these
# Predicted summary:  yummy
#
#
# Review: large dog normally soft mouthed destroy toys cloth chew ropes fuzzy animals several years old point went dinosaur like eight year old christmas morning though chewed absolutely bits weeks came apart twisted jagged chewed bits feared might present choking hazard might strong jaws normally use something toy triggered destructive lust though sure good bad point view mine hold well hoping
# Original summary: dog loved it but it was not that durable
# Predicted summary:  not bad but not bad
#
#
# Review: still think keurig idea best thing coffee since grinder problems mechanically machines put good coffee get keurig great job customer service experience buying tully roast quite love full flaver aroma fact pretty much buy tully brand coffee love kona blend favorite right although still tried ones would like try course especially good amazon puts italian roast sale really stock try like
# Original summary: almost my favorite cup
# Predicted summary:  great coffee
#
#
# Review: like plant much different easy take care would recommend plant anyone looking another different kind plant
# Original summary: olive tea tree
# Predicted summary:  great product
#
#
# Review: seen reviews complaining wait mix absorb water fridge really people cannot wait half hour burger want instant veggie burger microwaved time takes grab ketchup buy frozen burger think mix good better handmade veggie burgers look forward trying addendum eating lasagna made mix husband experienced horrible stomach bloating pain apparently glutton punishment though decided give another try made meatballs yesterday turn good usual ones sort rubbery texture really care blander texture overlook except product gave horrible stomach bloating pains gas ugh
# Original summary: mixed review convenient okay taste bad stomach problems
# Predicted summary:  not bad but not great
#
#
# Review: shipped every month best tasting larabar always carry around quick boost grams protein great energy booster
# Original summary: great after workout snack
# Predicted summary:  great product
#
#
# Review: health kick one personally love kind stuff excited try easy enough make brown ground beef drain add water pasta flavor pack add cheese surprisingly happy one lacked taste think enough cheese normal velveeta cheese buy store seemed lack cheese taste meal said done cheese seemed bit watery really enough ate one meal next day added bag frozen veggies also added salsa cheese tasted good think cheese comes meal one buy store really water lacked taste want try get velveeta add
# Original summary: just so so
# Predicted summary:  not bad but not great
#
#
# Review: item wonderful growing smaller crops several varieties consumption love white well see clean enjoy sprouts lettuce sandwiches salads even top soups decorate plates makes much easier takes little space thanks
# Original summary: great space saver
# Predicted summary:  great rice
#
#
# Review: little sachets packet three servings taste good neutral like neutral taste cracker dip dress wish little interference cracker taste sweet ever slightly soy sweet lightly salty sweet altogether quite nice cracker substantial enough carry heavy dip without breaking sodium sugar cracker serving nutritional info listed amazon thought would mention salty sweet remark altogether happy purchase probably donate crate packages local food bank recommend nice change crackers opened bunch little sachets put platter would great party cracker approx long wide enjoy
# Original summary: but nutrional neutral or negative depending on your view
# Predicted summary:  not bad but not great
#
#
# Review: using packets wabash valley farms whirley pop stovetop popcorn popper popcorn machine size ounce makes perfect pop love flavor movie theater popcorn one purchasing
# Original summary: just right
# Predicted summary:  great popcorn
#
#
# Review: tried detox teas weak flavor color impressed purchase
# Original summary: weak
# Predicted summary:  great tea
#
#
# Review: delicious cook sauce minutes pasta add shredded cheese top real treat used add robust browning half pound ground beef making meat sauce found sometimes nice let flavor sit add much dash olive oil pinch extra oregano pop oven minutes meal rivals restaurants area sure price amazon walmart score jar jars would reason recommend hit local walmart may higher grocery stores walmart cheap price totally recommend
# Original summary: so yummy
# Predicted summary:  not bad but not great
#
#
# Review: get better deal order subscription amazon three seven month old kittens devour fancy feast almost instantaneously moment serve
# Original summary: better prices on
# Predicted summary:  great product
#
#
# Review: coffee best smooth coffee ever nice robust flavor hint taste extra caffeine almost exclusively drink flavored coffee years prefer flavored wish available stores highly recommend
# Original summary: so great
# Predicted summary:  great coffee
#
#
# Review: attempts cut soda coffee intake decided drink tea healthier body many choices flavors choose originally found lipton pyramid tea bags totally intrigued found many different flavors took chance bavarian wild berry flavor even though never tried amazon offered good deal could pass box completed definitely say made right decision tea mainly drink cold find flavor strong try drink hot one best ice teas ever drank life also add sugar tea drinking cold definitely relieved teas taste good never drink soda
# Original summary: great ice tea
# Predicted summary:  not bad
#
#
# Review: great service received product quickly good condition would order
# Original summary: emergen
# Predicted summary:  great product
#
#
# Review: coffee tasted bitter like burnt cleaned machine still tasted bitter burnt order
# Original summary: not good
# Predicted summary:  tastes like plastic
#
#
# Review: used maggi years great happy find garlic seasoning great gravies brush meat soup base try
# Original summary: little extra zip
# Predicted summary:  great seasoning
#
#
# Review: excited order received okay little light taste discovered coffee going expire following week others going expire within days really going sell old coffee thank god able get refund
# Original summary: horrible
# Predicted summary:  great coffee
#
#
# Review: coffee hawaii best world kona side island exception
# Original summary: really good
# Predicted summary:  love this coffee
#
#
# Review: bottle small package big drank half bottle way gym hype good way feel tired bad feeling nothing love product continue buying
# Original summary: this little bottle is it
# Predicted summary:  not bad
#
#
# Review: big fan flavored coffee bought wife nice coffee base flavor vanilla overwhelming cloying
# Original summary: nice balance
# Predicted summary:  great coffee
#
#
# Review: found item grocery store years back seemed disappear found sooooooo happy everyone tried loves good thing comes big pack
# Original summary:
# Predicted summary:  love these
#
#
# Review: dog loves dental treats idea dogs like peppermint hesitant purchase first repeat customer alternate greenies dental treats variety make sure plenty fresh water handy since peppermint seems make dog thirsty
# Original summary: cool treat
# Predicted summary:  my dog loves these
#
#
# Review: product probably everyone bit expensive effective product really works lost lot water weight feel much better also lot energy sluggish lethargic clothes fit better people say look lot better less puffiness around eyes
# Original summary: great product although pretty pricey
# Predicted summary:  great product
#
#
# Review: took hot steaming bowl slightly sticky brown rice close perfect purposes review started eating rice right microwave texture great taste excellent rice alone great deal flavor subtle flavor good exactly would want brown rice taste good already thinking stars rice handy convenient easy fix tasty next thinking salsa chips thought hmmm salsa rice spooned medium salsa rice bowl stirred bit voila tasty meal think gets easier stuff make perfect base variety tasty meals fairly healthy ones big thumbs stars one
# Original summary: wow you all were right this is great stuff
# Predicted summary:  tasty and healthy
#
#
# Review: great dog treats old dog loves upset stomach perfect training since treat small purchased peanut butter salmon chicken flavors prefer peanut butter since least smelly
# Original summary: perfect for training
# Predicted summary:  my dog loves these
#
#
# Review: company name food taste good certainly poor job practicing preach bought couple bags lime chips least bit impressed granted bought cheap marked suffice say seems first person discover horrible taste otherwise people would buying regularly base exchange would getting desperate get rid even gob tostitos cheese dip taste chips barely tolerable
# Original summary: food should taste good really
# Predicted summary:  not bad
#
#
# Review: purchased month old know babies tend fluctuate interest eating baby enjoys gourmet food however like tender beef spinach matter tried changing flavor still eat strange loves spinach figure tasted flavors taste great rated stars product baby like would eat tender beef spinach
# Original summary: great flavor
# Predicted summary:  not bad
#
#
# Review: like tasty oil sesame oil one try good flavorful sesame oil perfect asian cooking tweaking traditional foods use touch flavor
# Original summary: excellent sesame oil
# Predicted summary:  great taste
#
#
# Review: big fan black cherry flavored soda kinds really enjoyed flavor drink know reviewers said sweet really matter preference like black cherry soda like drink definitely buying instead black cherry soda packs flavor really juice love fact gives vitamin day
# Original summary: loved it great alternative to black cherry soda
# Predicted summary:  not bad
#
#
# Review: beautiful plants great value well cared packaged perfectly thing would include future care instructions would like know cared seller continue care home people mist plants others soak bowl water method prefer making exclusive guy gal ordering plants others future super impressed thank
# Original summary:
# Predicted summary:  great bonsai
#
#
# Review: purchased pack great deal seen priced per bottle places great oil use frying impart overwhelming flavors foods keeps together high temps also good baking recipes reason use often cooking quite satisfied
# Original summary: really good value for this oil
# Predicted summary:  great price
#
#
# Review: himalayan splendor favorite tea start day energy alertness smooth good taste aroma smell enough get moving great mood fact wife tell cup himalayan splendor
# Original summary: very good and delicious
# Predicted summary:  great tea
#
#
# Review: stars really like chips thin crisp unlike market variations lot bbq taste another advantage much flavor tempted indulge evil dips contain hundreds fat ladden calories per tablespoon nice choice extravagant break carrot sticks one serving features plenty flavor crunchy mouth appeal pam mom blogger dieter
# Original summary: thin chip bbq goodness
# Predicted summary:  not the best
#
#
# Review: husband diabetic grandchildren healthy eaters year old parents eat pirate booty great time time snack ordered case father eat bag birthday present proceeded order family case thank much perfect snack
# Original summary: booty is the best snack for kids and adults
# Predicted summary:  great snack
#
#
# Review: amazing cats love exciting watch eat gobble like never eaten
# Original summary: my cats love this and cannot get enough
# Predicted summary:  cat loves it
#
#
# Review: taste carrots trying sneaky work small amount powder boost nutrition without detected said wegmans live pouch think bad considering organic packets plum happybaby anywhere except nurturme equivalent ounce jar typical four equal stage baby food jars tiny picture seems little deceptive think people see pic baby food jar think normal size ones tiny ones end paying getting less like said buy mix feed baby wanted try mix think cool concept paying double product ehh dunno might buy pack use mix
# Original summary: cool concept but expensive in the just ok
# Predicted summary:  not bad but not great
#
#
# Review: trouble keeping milk supply times choose believe actually helped little annoying take day long really think helped bad tasting either
# Original summary: need help try this
# Predicted summary:  great product
#
#
# Review: destiny deep sea water amazing looking pure natural water destiny deep sea water answer natural way help body nourish cleanse day pesticides preservatives body needs help made heal encourage try mary ann
# Original summary: amazing
# Predicted summary:  great stuff
#
#
# Review: dogs love undeniably odd basically packaged like old roller bottles deodorant hold front dog face lick rollerball one dogs wanted nothing puppy dove right lured wary dog trying love frankly though suspect would prefer food certainly like tossing treats dogs catch instead standing like holding looks like bottle deodorant lick might good dogs diet though treat bit flavor without many calories
# Original summary: like it more than like giving it to them
# Predicted summary:  my dogs love these
#
#
# Review: best sugar free crackers ever eaten best sweetened fruit juice sugar busters diet one snacks triscuits dress reduced fat triscuit satisfying finicky taste imo better ritz sometimes salty love eat stop hunger craving next meal put smuckers natural peanut butter satisfying snack promise think taste bad may become fav cracker nasty tastes anything negative one last thing come plastic bag feel compelled eat part roll take close box
# Original summary: the best
# Predicted summary:  great snack
#
#
# Review: full sized version candy miniature version intermediate size still works candy bowl arrived fresh quickly delicious
# Original summary: yummy tootsie rolls
# Predicted summary:  haribo gummi bears
#
#
# Review: careful expected sent total units lot better sellers whose advertising deceptive
# Original summary: misleading ad
# Predicted summary:  not what expected
#
#
# Review: received banana soft baked bar influenster pleasantly surprised yummy really tasted like banana nut bread love bar soft chewy stars looking place cannot find anyone knows find please comment let know
# Original summary: healthy snack great for on the go
# Predicted summary:  not bad
#
#
# Review: zico tetra pak favorite coconut water passion fruit favorite flavor coconut water everyone faint mild taste pleasant refreshing especially right workout tried pretty much every flavor every brand zico tetra pak best weird aftertaste brands like mango plain passion fruit favorite coconut water used strong sweet drinks looking healthier better tasting water might though stock zico says back distribution later summer cannot wait
# Original summary: my favorite and it is coming back soon
# Predicted summary:  great tasting and healthy
#
#
# Review: wife used product nothing good say told everyone good said brought real shine hair left soft would say best buy
# Original summary: outstanding
# Predicted summary:  not what expected
#
#
# Review: peek pom puppy loves mix dry food morning eats every bite like happy puppy saving cents automatic shipment
# Original summary: puppy loves it
# Predicted summary:  great product
#
#
# Review: reading reviews dogs getting sick hesitant make purchase usually purchase rawhide chips walmart could longer find stores area online finally decided hell give try surprised find large arrived sooner expected decent price black lab dachshund need small large chips able cut three five chips perfect chips last many months btw dogs never got sick chips know
# Original summary: rawhide chips
# Predicted summary:  great price
#
#
# Review: week placed order checking location didnt worry much still time till due date placed order ordered something else came happy one order arrived wondering happened seattles best coffee needless say said probably last time order amazon checked mail box placed went back made cup coffee worth wait next time may get level though say good try
# Original summary: great
# Predicted summary:  not the same
#
#
# Review: nasty overly salty artificial smoke flavor simply disappointing really taste like bacon texturally disappointing well instead light fluffy experience mayonnaise stuff runny gloppy dense would give zero stars possible
# Original summary: just get some bacon instead
# Predicted summary:  not bad
#
#
# Review: green tastes terrible water forms clumps fully dissolve buy worth money
# Original summary: low quality powder
# Predicted summary:  not bad
#
#
# Review: really good source goats milk found online amazon least expensive price found order regularly
# Original summary: love it
# Predicted summary:  great product
#
#
# Review: ordered great price yuck stock stale tastes like old iced ted left fridge toooo long first yogi tea flavor first box detox know supposed taste like worst part one ordered others seem fine far
# Original summary: yuck
# Predicted summary:  not the same
#
#
# Review: love coffee dark bitter finally found one like much jet fuel
# Original summary: yummy
# Predicted summary:  great coffee
#
#
# Review: disappointed order fortune cookies mostly broken although individually wrapped large number already opened loose box result cookies unusable stale even cookies still wrapped right crunch taste fresh
# Original summary: broken and stale cookies
# Predicted summary:  not bad
#
#
# Review: saved regular retail price local pet stores dog sick part due regular name brand dry foods many additives products hidden behind healthy label wellness allows feed dog food make sick pronounce ingredients loves healthy weight recipe despite diet formula dog living colitis limiting fat increasing fiber intake vital health food makes easy still regards treat six months starting eat bowl finicky eater spent hundreds dollars various diet foods vet pet boutiques first formula liked right bag relief five star product
# Original summary: awesom price awesome project
# Predicted summary:  great food
#
#
# Review: outstandingly good cereal sweet delicious healthy nice choice anyone wanting live healthy life
# Original summary: delicious and healthy
# Predicted summary:  great cereal
#
#
# Review: since joined weight watchers trying find better ways get hydration simply like plain water coworker introduced ice many flavors mango freak usually mango carry publix regularly plus tax getting subscription via amazon deal love stuff
# Original summary: weight watcher heaven
# Predicted summary:  love this stuff
#
#
# Review: bad would say good hazel nut vanilla nut really chocolate fan like good
# Original summary: this chocolate smells good when you open it though
# Predicted summary:  not bad
#
#
# Review: got sort grapefruit taste little energy drink type aftertaste aftertaste pronounced experienced drinks either really liked fact drinking get boost energy notice crash later either would say favorite energy drink bad either
# Original summary: no fear
# Predicted summary:  not bad
#
#
# Review: standby timothy german chocolate cake die tried delicious smells great tastes like warm chocolate glazed donut must try coffee
# Original summary: my new favorite
# Predicted summary:  delicious
#
#
# Review: sauce staple keep hand one better brands without going gourmet easy add additional spices desired
# Original summary: good flavor for big name brand
# Predicted summary:  great taste
#
#
# Review: local used carry costco miles away seems far travel bag chips finally subscribe save get regular basis like chips much good texture flavor hold dip well tried salt vineger cheese flavors plain still favorite
# Original summary: great chip
# Predicted summary:  love these chips
#
#
# Review: spicy chips lot great flavor warned left breath afterwards first time ate night even brushing flossing could taste mouth next morning careful eat especially hanging people later day
# Original summary: tasty but make sure you have gum
# Predicted summary:  not bad
#
#
# Review: love coffee waiting new shipment smart enough order making everyone around miserable kicking horse wifes best friend tell everyone make best coffee dreams kicking horse please tell amazon continue carry
# Original summary: love this coffee it is the smell of morning
# Predicted summary:  great coffee
#
#
# Review: eagle pack food dog eat loves gives healthy shiny coat friends dog suffering life threatening stomach troubles bad arthritis tried everything vets unable help finally found eagle pack stomach problems away able jump car walks without arthritic pain dog likes kibble canned food
# Original summary: only food my dog will eat
# Predicted summary:  my dog loves it
#
#
# Review: keurig coffee maker classroom dropping french vanilla cup knowing seconds warm french vanilla coffee aroma filling classroom great heavy coffee taste pleasant cup enjoy
# Original summary: great coffee
# Predicted summary:  great coffee
#
#
# Review: item something low acid found flavorful satisfying told low acid coffee never would known normally drink eight clock coffee happy brand would definitely drink tried second cup breakfast also cup afternoon another day normally drink coffee breakfast time stomach issues usually bothers stomach later day however actually able tolerate quite well used type coffee would drink daily afternoon nice know ever need little burst energy get day brew cup coffee worry getting upset stomach therefore definitely recommend giving coffee try
# Original summary: tasty cup joe
# Predicted summary:  great coffee
#
#
# Review: taylor south african kwazulu tea perfect tea anyone trying give coffee switched years ago rarely still enjoy really good cup clean interestingly blended freshly ground coffee occasionally expresso lemon zest day day morning dose wake caffeine jangle irish nerves upset tummy kwazulu tea perfect try see think female
# Original summary: the perfect tea for anyone to give up coffee
# Predicted summary:  great tea
#
#
# Review: cup tea cup harney sons paris tea discovered harney sons paris realize tea could taste delicious elegant lovely comes beautiful tin love silk bags difficult return grocery store brands trying price harney sons taken something simple tea elevated whole new level highly recommended
# Original summary: affordable delicious luxury
# Predicted summary:  great tea
#
#
# Review: great taste easy use find let package soak hot water minutes use makes oil come package easier
# Original summary: great taste
# Predicted summary:  great taste
#
#
# Review: pet sitter first introduced lammy bites year old picky eater really gets excited time nightly treat lammy bites finicky eater try piece food probably happier dog
# Original summary: treat your best friend with the best
# Predicted summary:  my cats love it
#
#
# Review: feel deprived trying shed pounds really made huge difference pizza favorite
# Original summary: carb quik is life saver
# Predicted summary:  great taste
#
#
# Review: buy product vegan important factor taste
# Original summary: vegan
# Predicted summary:  not as good as the original
#
#
# Review: real fruit juices underwhelming say least best far izze fruit juice carbonated water added sugars comes along switch switch fruit juice carbonation added like izze really like drink different izze drinks switch blends juices different achieve little subtle flavor izze tang punch cannot say one better deliver different refreshing experience tried switch orange tangerine black cherry orange tangerine good highly recommend black cherry good better cherry drinks sort could bit better quite deliver flavor experience really good black cherry soda
# Original summary: great alternative to high fructose corn syrup laden sodas
# Predicted summary:  not bad but not great
#
#
# Review: great light crispy greasy love fact unsalted almost impossible find
# Original summary: perfect potato chips
# Predicted summary:  best chips ever
#
#
# Review: drink coconut water every day house become somewhat obsession used subscription pack vitacoco ran tried instead like better tastes cleaner though cannot describe different feel better drinking drinking vitacoco coconut water general odd taste still really sweet feels refreshing drink really hungry drink meals kind like protein shake energy drink settles stomach gives fantastic burst energy
# Original summary: refreshing and amazingly satisfying
# Predicted summary:  tastes like medicine
#
#
# Review: love coffee hate side effects upset stomach drink cup two breakfast blend best love taste love smell love fact everyday drink one two three cups coffee never upsets stomach love love
# Original summary: coffee and this one does not upset my stomach
# Predicted summary:  great coffee
#
#
# Review: discovered yellow label trip japan arrived meeting time wonder around market really rubber bought familiar lipton label well several teas yellow label little pronounced flavor marketed brisk lipton tea tea drinker probably enjoy flavor worst part brewing drinking yellow label trying get rid box standard lipton brisk tea already sitting pantry
# Original summary: better than us marketed lipton tea
# Predicted summary:  not the same
#
#
# Review: chips bad taste little money would pay bag healthy chips
# Original summary: not bad
# Predicted summary:  not bad
#
#
# Review: balsamic favorite vinegar use make dressings add deviled eggs glazes sauces staple many dishes generic inexpensive balsamic okay use purposes gourmet balsamic best reductions tried using inferior vinegar make reduction sauce dessert turn fattoria gives stronger flavor salad dressings reductions taste rich sweet
# Original summary: the best balsamic have ever used
# Predicted summary:  great product
#
#
# Review: found branston pickle unappealing bit tangy pallet read great beef cheddar cheese sandwiches personally think reminds chunky kick look forward finding obscure uses british delight american home
# Original summary: when used correctly
# Predicted summary:  not the same
#
#
# Review: got huge coffee fan always looking summer drink cool instead hot chilled got glass ice popped top poured none cream color like coffee straight almost got made little sweet cream sweet tell would rather cream sweetener day week drink cold black coffee tastes better
# Original summary: illy issimo coffee drink
# Predicted summary:  not the best
#
#
# Review: forced doctor severely cut intake coffee permanently still enjoy small cups day thank heavens lipton decaffeinated green tea come rescue case desire drink beyond huge music fan usually listening vast collection work seem always want hot soothing beverage sip pass hours listen lipton green tea great extremely easy make good naturally decaffeinated clean pure taste lipton tea come known think hooked life buying packet boxes local store highly recommend like wishing cut even completely eliminate daily dose traditional caffeinated coffee
# Original summary: on the stomach and does not keep you awake
# Predicted summary:  great coffee
#
#
# ...
# Original summary: tasting granolas have tried dark chocolate and red berries
# Predicted summary:  not as good as the other brands
#
#
# Review: first saw item hawaii item available via trader joe whole foods local retail distributor circumstances would reorder price brought line alternatives example equivalent amount flavored crystal geyser sells fluid ounces math price required amazon selection absolutely outrageous include shipping cannot recommend produce good conscience outrageously overpriced
# Original summary: overpriced arrowhead water
# Predicted summary:  great price
#
#
# Review: eat bowl like cereal yogurt handful good love real fruit little girl especially loves yogurt staple house price amazon actually quite good compared see stores
# Original summary: this is where bakery on main really shines granola
# Predicted summary:  great cereal
#
#
# Review: used several types brownie mixes years best ever used largest boxed mix issue live alone making full box bit much break well cut added amounts water oil except eggs works well enjoy fresh warm batch brownies desired moist chewy chocolate brownie mix taste like scratch made price also good would gladly suggest others try brand enjoy
# Original summary: the best boxed mix ever
# Predicted summary:  great for the movies
#
#
# Review: package get three varieties popcorn different light fluffy fun eat two hulless variety purple kind thick kernel uniquely nutty taste stand kind butter salt seasonings might throw way highly recommend starter package nice gift one corn poppin friends
# Original summary: great oil popping popcorn
# Predicted summary:  not bad but not great
#
#
# Review: used drink dieters green often read senna good consume frequently reduced intake dieters green made tummy hurt little started drink later bother much actually ordered dieter green seller gave super slimming one instead pretty bummed first figured would give try ended blessing disguise slimming one sort dieter green really make tummy hurt like dieters green really love
# Original summary: me the wrong one but it is still good
# Predicted summary:  great taste but not great
#
#
# Review: low price spice compared grocery store find use lot white clam sauce mashed potatoes white sauces types anywhere want black flecks pepper large amounts frozen protect freshness
# Original summary: good pepper
# Predicted summary:  not what expected
#
#
# Review: looking great coffee drinkers degree outside definitely ordering
# Original summary: mmmmmmmm yum
# Predicted summary:  great coffee
#
#
# Review: baby months ago always tired sleepy cranky drinking tea one week back pain headache gone energy never tired anymore younger always heard ganoderma never chance try back days ganoderma rare expensive people think box expensive growing parents drink sometimes one box cost thousands product available cheap cannot wait drink tea everyday btw one teabag makes cups use teabags pitcher put fridge lasts days
# Original summary: magical ganoderma
# Predicted summary:  great tea
#
#
# Review: worst energy drink ever tasted really big spicy flavor drink spicy drink powers impossible even finish one six even tried giving five away free people would thing throw away really spent drain
# Original summary: why does it taste spicy ewww
# Predicted summary:  not bad
#
#
# Review: found little doughy followed actual directions crispy delicious crust every time roll directed place oven ten minutes without toppings used pizza stone flip dough top slightly crispy side bottom put toppings best gluten free pizza dough tasted yet
# Original summary: love this stuff with little modification
# Predicted summary:  not bad
#
#
# Review: one thing found premade coffee latte drinks overload sweetener kills case excellent flavor great ice
# Original summary: very good true coffee drink without the sweet overload
# Predicted summary:  great coffee
#
#
# Review: like black tea bitter taste love tea really good flavor smells nice bitter taste
# Original summary: zen
# Predicted summary:  not bad
#
#
# Review: great keep bostons teeth clean watch choking always watch eat take away gets last inches pull throat choking buy large ones even though smaller dog every night goes pantry door beg loves smell funny eats washable blanket yes pampered pooch mom
# Original summary: nice teeth
# Predicted summary:  my dog loves them
#
#
# Review: got sample influenster summer voxbox thought bar definitely microwaved tastes way better warm cold wish quaker would upped amount spices bar thought little bland
# Original summary: banana nut bread
# Predicted summary:  great taste
#
#
# Review: gallon gas even gas goes heat every time sees gas station tad cheaper switch sweet grams sugar much produces eight ounce calories drink ounce container drink get calories regular coke pepper fewer grams sugar therefore fewer calories compared switch colored water calling juice probably permitted government whomever sets words practice mostly carbonated water guess carbonating water makes expensive expensive taste pleasant lagging post taste bottom line buy store buy anywhere probably cost per unit compared calculate especially every penny important
# Original summary: pricey sweet colored water
# Predicted summary:  great alternative to soda
#
#
# Review: wife liked drink pretty good tasted similar sparkling drinks buy non alcoholic apple flavor figure apple taste since ingredients would say would great special drink every days far drinking every day day would like much
# Original summary: pretty good tasting not your everyday drink
# Predicted summary:  tastes like like it
#
#
# Review: bought first sproutmaster years ago dowling orchard market passing banning california bit pricey plastic tray cannot complain ease use quality sprouts grown divider helpful grow different sprouts helpful grow type sprout two different stages growth way always fresh sprouts handy anytime grow fast sprout master makes simple care
# Original summary: so simple even my child would do it
# Predicted summary:  great tasting
#
#
# Review: stuff easy make scratch waste money google horchata million recipes
# Original summary: make your own
# Predicted summary:  great taste
#
#
# Review: heard chips thought would good alternative regular chips could eat though taste good personally grandmother loved though gave rest
# Original summary: didn like the taste
# Predicted summary:  great chips
#
#
# Review: various brands pasta found bionaturae best quality taste satisfaction
# Original summary: gluten free and super good
# Predicted summary:  great pasta
#
#
# Review: really good tasty candies really like however price paid thru amazon order around daughter bought
# Original summary: brookside dk
# Predicted summary:  yummy
#
#
# Review: home first washed area pressure washer washed away used product kill residual close roof flashing use product day temperature degrees higher show much difference days later looking section roof still looked green try late spring next year see produces better result one generous application done job pleased repeated application june happy say moss spray worked like wonder moss growing roof facing north completely dead vigorous shaking bottle required little push button next spray gun must completely pushed give star rating
# Original summary: happy
# Predicted summary:  great product
#
#
# Review: recommended vet since chester handle wheat products well therefore cannot greenies teeth becoming mess vet recommended product loves made noticeable difference
# Original summary: chester loves these
# Predicted summary:  great product
#
#
# Review: comes cereal love product agree others best tasting cereal marker however also agree others price fluctuations annoying cancel subscription price longer cheaper local store offering price reasonable even though still paid first time pack pack buy lesson learned next time price goes buy multiple order
# Original summary: that is why stars but not the price fluctuations
# Predicted summary:  great cereal
#
#
# Review: like corn pops without sugar want sweet throw spoonful splenda top sometimes mix calorie dense breakfast cereals increase volume without increasing waist line also make great snack eat plain basically love product
# Original summary: great for breakfast or snack
# Predicted summary:  great taste
#
#
# Review: local rite aid store sale saltiest worst chips every awful never buy like barbecue ones
# Original summary: too salty
# Predicted summary:  love these chips
#
#
# Review: would give candy five stars except fact packaging comes distinct chemical smell like silicone edge something else know plastic printing multiple chemical sensitivities may want someone else open put candy another container deal chemical stink fwiw candy seem pick smell maybe ink outside pack found smell offensive dumped candy bowl got rid packaging asap stinky sorry tasty people make great gummy question packaging may taint experience
# Original summary: fantastic candy stinky packaging
# Predicted summary:  not the same
#
#
# Review: read black rice could find looked amazon delicious nutty flavor love keep fridge snack black way purple
# Original summary: chinese black rice
# Predicted summary:  delicious
#
#
# Review: bought share office disappeared almost instantly good contain enough protein keep people going suppressing snacky feeling great snack carry light highly recommend try flavors well snack chicken turkey beef various flavors
# Original summary: very tasty
# Predicted summary:  great snack
#
#
# Review: good caffeine definitely bad opinion makes water taste like energy drink went flat ever tasted flat red bull warm flat red bull imo pretty close flavor except nearly syrupy red bull may like others may surprised odds better either direction
# Original summary: flavor green thunder butt
# Predicted summary:  not bad
#
#
# Review: cooked rice noodles gummy loose version noodle cut pieces slide serving spoon type noodle definitely acquired taste goodness eat plate almost noodles without consuming carbs many calories compelling combination expect taste like noodles disappointed eat open mind good thick sauce pieces meat shrimp sausage part dish vegetables well think might enjoy love love first sight think real noodles beyond shape little common noodles good news calories carbs gluten good news smaller bags shirataki noodles used pay store buying bargain enjoy
# Original summary: no calories no carbs gluten free
# Predicted summary:  not bad but not great
#
#
# Review: flavor tart tastes like slightly sweetened cranberry spritzer little sais know french translates know must flavors monk fruit listed ingredients familiar flavors like overly sweet people little put flavor stevia tastes nice refreshing pleased list ingredients natural mere calorie count pretty great lovely tastes good perform hunger curbing drank afternoon trip gym late lunch ate lunch two hours later think worked
# Original summary: tart refreshing and curbs appetite
# Predicted summary:  not bad but not great
#
#
# Review: olive oil terrific love dip garlic bread use sauces slight fruity taste fabulous seen pros use many times superolive shipped super fast
# Original summary: frantoia extra virgin olive oil
# Predicted summary:  great taste
#
#
# Review: cheap fake nothing like real emerald nuts buy store complete waste money dont get ripped like
# Original summary: no good
# Predicted summary:  not the same
#
#
# Review: salmon jerky right texture right moisture right chewiness perfect salmon jerky sadly completely messed oversalting throwing salt eating packs evening actually woke thirst middle night drink water twice would feed dog
# Original summary: way too salty
# Predicted summary:  not bad
#
#
# Review: bought chocolate times box bars precise loved every bit pun intended orange kind light energizing feels really rich inside mouth organic main reason bought took get shipped recommend lovers fine organic products
# Original summary: you nice light but rich taste in the mouth
# Predicted summary:  not the same
#
#
# Review: like taste sweet sweet aftertaste pleasant drink chilled room temperature like refreshing tea drink try annoyance hard mix suggest sipping little water bottle pouring mix make easier agitate
# Original summary: this you even get workout when you shake it
# Predicted summary:  tastes like tea
#
#
# Review: bullmastiff rottweiler shih tzu many come bag big dogs might worth spend money broke quarters shih tzu due many pet food treat recalls last couple years wary many things feed pets made made comfortable things made china stock small dog price buy large dogs
# Original summary: my dogs loved these
# Predicted summary:  my dog loves it
#
#
# Review: dog loves treats great quality cheaper buying big box stores really cannot wrong
# Original summary: can go wrong
# Predicted summary:  great treats
#
#
# Review: quaker oatmeal cookies tastey make easy snack work individually wrapped put bag cookie soft nice bits nuts chocolate little dry perfect milk brainer good cookie individually wrapped living
# Original summary: good cookie for on the go
# Predicted summary:  great cookies
#
#
# Review: popchips really great snack alternative regular chips full replacement far concerned taste texture great jalapeno ones hate greasy fried chips often switch baked version chips another choice popped like flavored chips want something crunchy great taste owe self try bag potato popchips
# Original summary: great alternative to regular chips
# Predicted summary:  not bad
#
#
# Review: sweet dark chocolatey gluten free artificial sweeteners really holds hunger bay handy snack mini meal much prefer typical low carb bar
# Original summary: satisfies
# Predicted summary:  great taste
#
#
# Review: ordering cashews months total probably shipments quality consistently high right amount salt enjoy much healthy snacks definitely continue order
# Original summary: very tasty yummy
# Predicted summary:  great taste
#
#
# Review: purchase coffee makers gifts mom dad work great problem prices great
# Original summary: great coffee maker
# Predicted summary:  great coffee
#
#
# Review: ordered draw faces candy coated marshmellow pops son bday party worked great
# Original summary: perfect for writing on candy coated pops
# Predicted summary:  not what expected
#
#
# Review: particular packages taste however seller gave complete refund even make send back ordered item fine
# Original summary: think got bad batch
# Predicted summary:  not what expected
#
#
# Review: bought pepper grinder found actually grind extremely well sure well grinders would work pleasantly surprised well work
# Original summary: great salt grinder
# Predicted summary:  not the best
#
#
# Review: bars tasty really taste like brownie certainly chocolatey yummy good amount protein good afternoon snack trying gain muscle mass best thing workout contain almost carbs know proper nutrition know important carbs workout though good bar buy
# Original summary: pretty good for protein bar
# Predicted summary:  great snack
#
#
# Review: really like taste powder great protein shake especially banana blended issue shelf life product container lasts long time container purchased amazon expired less month purchase date noticed date production exactly year ago protein powders shelf life couple years
# Original summary: good in smoothies but why the short shelf life
# Predicted summary:  great product but overpriced is expensive
#
#
# Review: doctor recommended try fenugreek increase milk supply within hours noticed increase week able freeze one bag milk every day going continue take supplement return work keep supply take capsules times day
# Original summary: increased milk supply
# Predicted summary:  great product

# %%
  print("Review:",seq2text(x_val[3]))
  print("Original summary:",seq2summary(y_val[3]))
  print("Predicted summary:",decode_sequence(x_val[3].reshape(1,max_len_text)))
# Out:
# Review: bought dollar tree yummy taste like french fries crunchy going buy bulk pass kid test
# Original summary: yum
# Predicted summary:  best crackers ever
